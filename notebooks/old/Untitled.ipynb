# %%
import unified_ar.general.utils as utils

a=utils.loadState('meta_dataset/220815_22-17-14-Home1-s=1 0')
a.keys()
# Out:
# dict_keys(['meta_features', 'meta_targets'])

# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import backend as K
# import keras
import numpy as np

model = Sequential()

model.add(Dense(1, input_shape=(10,)))

optimizer = keras.optimizers.Adam(lr=0.01)
model.compile(loss='mse', optimizer=optimizer)

print("Learning rate before first fit:", model.optimizer.learning_rate.numpy())

model.fit(np.random.randn(50000,10), np.random.randn(50000), epochs=50)
print("Learning rate after first fit:", model.optimizer.learning_rate.numpy())
# Change learning rate to 0.001 and train for 50 more epochs
K.set_value(model.optimizer.learning_rate, 0.001)
print("Learning rate before second fit:", model.optimizer.learning_rate.numpy())

model.fit(np.random.randn(50000,10), 
          np.random.randn(50000), 
          initial_epoch=50, 
          epochs=50)
# Out:
# Learning rate before first fit: 0.01
# Epoch 1/50
# 1563/1563 [==============================] - 1s 601us/step - loss: 1.0955
# Epoch 2/50
# 1563/1563 [==============================] - 1s 628us/step - loss: 1.0163
# Epoch 3/50
# 1563/1563 [==============================] - 1s 648us/step - loss: 1.0109
# Epoch 4/50
# 1563/1563 [==============================] - 1s 614us/step - loss: 1.0103
# Epoch 5/50
# 1563/1563 [==============================] - 1s 601us/step - loss: 1.0222
# Epoch 6/50
# 1563/1563 [==============================] - 1s 601us/step - loss: 1.0100
# Epoch 7/50
# 1563/1563 [==============================] - 1s 652us/step - loss: 1.0136
# Epoch 8/50
# 1563/1563 [==============================] - 1s 654us/step - loss: 1.0072
# Epoch 9/50
# 1563/1563 [==============================] - 1s 633us/step - loss: 1.0138
# Epoch 10/50
# 1563/1563 [==============================] - 1s 630us/step - loss: 1.0283
# Epoch 11/50
# ...

# %%
import logging
log_filename='logs/a.log'
logging.basicConfig(level=logging.DEBUG,
                    format='[%(asctime)s] %(filename)-10s %(funcName)-10s %(levelname)-8s %(message)s',
                    handlers=[logging.FileHandler(log_filename), logging.StreamHandler(sys.stdout)],
                    datefmt='%H:%M:%S')
logger = logging.getLogger("mylog")
logging.getLogger().setLevel(logging.DEBUG)
logger.debug('a')
# logging.getLogger().handlers
# Out:
# [20:55:48] 1341575357.py <cell line: 9> DEBUG    a

# %%
logging.getLogger().handlers[0].baseFilename[:-3]
# logger.debug('a')
# Out:
# '/raid/home/labusermodaresi/environments/ictai/UnifiedAR/log'

# %%
from pathlib import Path
path = Path("here/your/path/file.txt")
print(path.parent.)
# Out:
# /raid/home/labusermodaresi/environments/ictai/UnifiedAR/here/your/path

# %%
path.parent.rel
# Out:
# PosixPath('here/your/path')

# %%
import unified_ar.general.utils as utils
utils.reload()
import unified_ar.general.libinstall
from constants import methods
import pandas as pd
import numpy as np
datasetdscr = methods.dataset[2]['method']().load()
print(f'dataset={datasetdscr.data_dscr}')
datasetdscr.activities_map
# Out:
# 100%|██████████| 16/16 [00:00<00:00, 1610.37it/s]
# =================== The required libraries have been  installed ===================
# dataset=Aruba
# {0: 'None',
#  1: 'Bed_to_Toilet',
#  2: 'Eating',
#  3: 'Enter_Home',
#  4: 'Housekeeping',
#  5: 'Leave_Home',
#  6: 'Meal_Preparation',
#  7: 'Relax',
#  8: 'Respirate',
#  9: 'Sleeping',
#  10: 'Wash_Dishes',
#  11: 'Work'}

# %%
# datasetdscr.__dict__.keys()
# datasetdscr.__dict__['activity_events']
# setattr(datasetdscr,'ali',datasetdscr.__dict__['activity_events'])
datasetdscr.ali
# Out:
#                       StartTime                    EndTime  Activity  \
# 0    2010-11-04 00:03:50.209589 2010-11-04 05:40:43.642664         9
# 1    2010-11-04 05:40:51.303739 2010-11-04 05:43:30.279021         1
# 2    2010-11-04 05:43:45.732400 2010-11-04 08:01:12.282970         9
# 3    2010-11-04 08:11:09.966157 2010-11-04 08:27:02.801314         6
# 4    2010-11-04 08:33:52.929406 2010-11-04 08:35:45.822482         6
# ...                         ...                        ...       ...
# 6435 2011-06-11 17:58:01.269227 2011-06-11 18:14:30.112460         7
# 6436 2011-06-11 18:17:06.835188 2011-06-11 20:33:44.453476         7
# 6437 2011-06-11 20:51:40.625871 2011-06-11 21:18:10.632466         7
# 6438 2011-06-11 21:18:58.841500 2011-06-11 22:05:07.486416         7
# 6439 2011-06-11 22:10:29.729309 2011-06-11 23:58:10.004834         9
#
#                    Duration
# 0    0 days 05:36:53.433075
# 1    0 days 00:02:38.975282
# 2    0 days 02:17:26.550570
# ...

# %%
# x=pd.DataFrame(a['meta_features'])
# # x['dayofweek']=x.time.dt.day_of_week
# y=pd.DataFrame(a['meta_targets'])
# filter_bad_th=y.accuracy.quantile(.2)
# x=x.loc[y.accuracy>filter_bad_th]
# y=y.loc[y.accuracy>filter_bad_th]

d=a

# %%
def a():
	# yield 1, None
	return
b=a()
if b:
	for x,y in b:
		print(x,y)

# %%
feat_df = pd.DataFrame(d['meta_features'])
target_df = pd.DataFrame(d['meta_targets'])
filters=target_df.notna()['size']
filters &=target_df.method=='FixedSlidingWindow'
feat_df=feat_df.loc[filters]
target_df=target_df.loc[filters]
# target_df['method']=1
# target_df['size']=1
# target_df['shift']=1
# print(feat_df.describe())
ntarget = target_df.drop(['accuracy', 'precision', 'recall', 'f1'], axis=1,errors='ignore',)
from segmentation.MetaDecomposition import MyTargetTransformer
self=utils.Data('test')
self.create_feat_transformer=create_feat_transformer
self.meta_mode='keras1'
self.targetTransformer = MyTargetTransformer(self.meta_mode)
self.targetTransformer.fit(ntarget)
self.featTransformer = self.create_feat_transformer(feat_df)
self.featTransformer.fit(feat_df)
# print(f"metainfo=============== \nfeat={feat_df}\n target={target_df}")
X = self.featTransformer.transform(feat_df)
y = self.targetTransformer.transform(ntarget)
if self.meta_mode == 'keras':
	from tensorflow import keras
	from tensorflow.keras import layers
	# Define model
	inputs = keras.Input(shape=(X.shape[1],))
	# layer=keras.layers.BatchNormalization(input_shape=tuple([X.shape[1]]))

	layer=keras.layers.Dense(3, activation='relu')(inputs)
	# layer=keras.layers.Dropout(rate=0.5)(layer)
	layer=keras.layers.BatchNormalization()(layer)
	layer=keras.layers.Dense(3, activation='relu')(layer)
	# layer=keras.layers.Dropout(rate=0.5)(layer)
	layer=keras.layers.BatchNormalization()(layer)
	layer=keras.layers.Dense(3, activation='relu')(layer)
	# layer=keras.layers.Dropout(rate=0.5)(layer)
	# layer=keras.layers.Dense(2,   activation='sigmoid')(layer)
	classifier = layers.Dense(1, activation='softmax', name='method')(layer)
	regressions = [layers.Dense(1, activation='linear', name=x)(layer) for x in ntarget.columns.drop('method')]
	mdl = keras.Model(inputs=inputs, outputs=[classifier, *regressions])
	mdl.compile(loss=['categorical_crossentropy', *(['mse']*len(regressions))], optimizer='adam', metrics=['accuracy'])
	# model.compile(loss="categorical_crossentropy", optimizer="adadelta",metrics=["accuracy"])
	# print(mdl.summary())
	# # inputs = keras.Input(shape=(X.shape[1],))
	# inputs= keras.layers.normalization.BatchNormalization(input_shape=tuple([X.shape[1]]))
	# layer1 = keras.layers.core.Dense(32, activation='relu')(inputs)
	# layer1b= layers.BatchNormalization(layer1)
	# layer2 = layers.Dense(16, activation='relu')(layer1b)
	# layer2b= layers.BatchNormalization(layer2)
	# layer3 = layers.Dense(16, activation='relu')(layer2b)
	# layer3b= layers.BatchNormalization(layer3)
	# classifier = layers.Dense(1, activation='softmax', name='method')(layer3)
	# regressions = [layers.Dense(1, activation='linear', name=x)(layer3) for x in ntarget.columns.drop('method')]

	# mdl = keras.Model(inputs=inputs, outputs=[classifier, *regressions])

	# mdl.compile(loss=['categorical_crossentropy', *(['mse']*len(regressions))], optimizer='adam', metrics=['accuracy'])
else:
	from sklearn.svm import SVR
	from sklearn.multioutput import MultiOutputRegressor
	mdl = MultiOutputRegressor(SVR())
from sklearn.model_selection import train_test_split, GridSearchCV, cross_validate
x1,x2,y1,y2=train_test_split(X,y,test_size=.3)
mdl.fit(x1, y1)#,batch_size=100,validation_split=.2,)
self.ml = mdl

# %%
mdl.score(X,y)
# Out:
# 0.5141641191632198

# %%
1 if ' ' else 2
# Out:
# 1

# %%
import matplotlib.pylab as plt
z=self.targetTransformer.inverse_transform(mdl.predict(X))

gt=ntarget.reset_index()
for c in z.columns:
	plt.plot(gt[c])
	plt.plot(z[c])
	from sklearn.metrics import mean_squared_error,mean_absolute_error
	print(c,mean_absolute_error(gt[c],z[c]))
	plt.show()
# mdl.predict(X)
# Out:
# size 11.484372554023697
# shift 12.137073631387002

# %%
mdl.fit(X, y,batch_size=2,validation_split=.2,)
# Out:
# 39/39 [==============================] - 1s 3ms/step - loss: nan - method_loss: nan - size_loss: nan - method_accuracy: 0.1667 - size_accuracy: 0.0000e+00 - val_loss: nan - val_method_loss: nan - val_size_loss: nan - val_method_accuracy: 0.1500 - val_size_accuracy: 0.0000e+00

# %%
from tensorflow import keras
from tensorflow.keras import layers
# Define model
model = keras.models.Sequential()
model.add(keras.layers.BatchNormalization(input_shape=tuple([X.shape[1]])))
model.add(keras.layers.Dense(32, activation='relu'))
model.add(keras.layers.Dropout(rate=0.5),name='e')
model.get_layer('e')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /raid/home/labusermodaresi/environments/ictai/UnifiedAR/Untitled.ipynb Cell 4 in <cell line: 7>()
#       <a href='vscode-notebook-cell://ssh-remote%2Blissi.alimodaresi.ir/raid/home/labusermodaresi/environments/ictai/UnifiedAR/Untitled.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> model.add(keras.layers.BatchNormalization(input_shape=tuple([X.shape[1]])))
#       <a href='vscode-notebook-cell://ssh-remote%2Blissi.alimodaresi.ir/raid/home/labusermodaresi/environments/ictai/UnifiedAR/Untitled.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> model.add(keras.layers.Dense(32, activation='relu'))
# ----> <a href='vscode-notebook-cell://ssh-remote%2Blissi.alimodaresi.ir/raid/home/labusermodaresi/environments/ictai/UnifiedAR/Untitled.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> model.add(keras.layers.Dropout(rate=0.5),'e')
# ...

# %%
def create_feat_transformer(feat):
        import numpy as np
        from sklearn.compose import ColumnTransformer
        from sklearn.datasets import fetch_openml
        from sklearn.svm import SVC
        from sklearn.pipeline import Pipeline
        from sklearn.impute import SimpleImputer
        from sklearn.preprocessing import StandardScaler, OneHotEncoder
        from sklearn.linear_model import LogisticRegression
        from sklearn.model_selection import train_test_split, GridSearchCV, cross_validate
        from sklearn.pipeline import make_pipeline
        from sklearn.ensemble import HistGradientBoostingRegressor
        from sklearn.multioutput import MultiOutputRegressor
        from sklearn.preprocessing import SplineTransformer
        from feature_extraction.features import TimeSpliter, periodic_spline_transformer

        numeric_features = feat.columns.drop(['time'])
        numeric_transformer = StandardScaler()

        preprocessor = ColumnTransformer(
            transformers=[
                ("num", numeric_transformer, numeric_features),
                ('date', make_pipeline(TimeSpliter(), ColumnTransformer(
                    transformers=[
                        ("weekday", periodic_spline_transformer(7, n_splines=3), ["time_dayofweek"]),
                        ("month", periodic_spline_transformer(12, n_splines=6), ["time_month"]),
                    ]
                )), ['time']),
            ]
        )

        return preprocessor
        # y=target.loc[target['method']=='FixedSlidingWindow'][['size','shift']]

# %%
import pandas as pd
from IPython.display import display
# display(res)
acts = dataset[t].activities_map.copy()
del acts[0]
acts['avg'] = 'avg'
actres = {}
res['b']=res['a']
for k in acts:

	# if(k==0):continue
	if (k == 0):
		continue
	key = acts[k]
	if key == 'avg':
		actres[key] = {(key,m, e): res[m]['avg'][e] for m in res for e in res[m]['avg']}
	else:
		actres[key] = {(key,m, e): res[m][k]['avg'][e] for m in res for e in res[m][k]['avg']}
	print(f'act={key}==============================')
#                 print(actres[k])
	if (len(actres[key]) == 0):
		print('No Eval')
	else:
		df2 = pd.DataFrame(actres[key]).round(2)
		display(df2)
# Out:
# act=Bathing==============================
#             Bathing                                                           \
#                   a                                                        b
#           existance total dur. relative dur. alignment cardinality existance
# tp             3.00    2587.64          2.46      2.14        3.00      3.00
# fp             0.00      10.36          0.01      0.02        0.00      0.00
# fn             3.00    3749.66          3.54      0.84        3.00      3.00
# precision      1.00       1.00          1.00      0.99        1.00      1.00
# recall         0.50       0.41          0.41      0.72        0.50      0.50
# f1             0.67       0.58          0.58      0.83        0.67      0.67
#
#
#
#           total dur. relative dur. alignment cardinality
# tp           2587.64          2.46      2.14        3.00
# fp             10.36          0.01      0.02        0.00
# fn           3749.66          3.54      0.84        3.00
# ...

# %%
# df2.rename({'a':'v'},axis=1,level=1)
df2.loc['f1']['avg'].mean()
# Out:
# 0.34800000000000003

# %%
from ipywidgets import interact, interactive, fixed, interact_manual,widgets
import unified_ar.result_analyse.resultloader
import unified_ar.result_analyse.kfold_analyse as an
import unified_ar.metric.MyMetric as mymetric
import unified_ar.general.utils as utils
import unified_ar.result_analyse.visualisation as vs
from ipywidgets import Button, Layout

@interact
def datasets(dataset=['Home1','Home2','A4H','VanKasteren']):
    @interact_manual
    def compare(files=widgets.SelectMultiple(options=result_analyse.resultloader.get_runs_summary(dataset), description='Files',           layout=Layout(width='100%', height='180px')),titles="comma seperated"):
        print(files)
        run_info={}
        dataset={}
        evalres={}
        res={}
        titles=titles.split(',')
        for i, file in enumerate(files):
            print(i,file)
            t=titles[i]
            run_info[t],dataset[t],evalres[t]=utils.loadState(file)
            print(evalres[t])
            for i in evalres[t]:
                evalres[t][i].Sdata=None
                
            dataset[t].sensor_events=None
            res[t]=an.mergeEvals(dataset[t],evalres[t],mymetric)
        res={t:res[t] for t in sorted(res.keys())}
        vs.plotJoinMetric(res,[k for k in res[t]],dataset[t].activities_map)

# %%
import unified_ar.result_analyse.resultloader
import unified_ar.general.utils as utils

for file in result_analyse.resultloader.get_runs():
    summary=utils.loadState(file[1],'summary')
    #print(summary['folds'][0]['quality']['f1'])

# %%
import unified_ar.result_analyse.resultloader
import unified_ar.general.utils as utils

for file in result_analyse.resultloader.get_runs():
    try:
        utils.loadState(file[1],'summary')
    except:
        try:
            run_info,dataset,evalres=utils.loadState(file[1])
            print(file[1])
            if(type(evalres)==type([])):
                for k in range(len(evalres)):
                    if('shortrunname' not in evalres[k].__dict__):
                        evalres[k].shortrunname='A'
                        evalres[k].functions={}
                utils.saveState([run_info,dataset,{k:evalres[k] for k in range(len(evalres))}],file[1])
                run_info,dataset,evalres=utils.loadState(file[1])

            compressdata={'run_info':run_info, 'folds':{k:{'quality':evalres[k].quality,'shortrunname':evalres[k].shortrunname,'functions':evalres[k].functions if 'functions'in evalres[k].__dict__ else {}} for k in evalres}}
            utils.saveState(compressdata,file[1],'summary')
        except:
            print('error in',file[1])

# %%
import unified_ar.result_analyse.kfold_analyse as an
import unified_ar.metric.MyMetric
import unified_ar.general.utils as utils
import unified_ar.result_analyse.visualisation as vs
# run_info2,dataset2,evalres2=utils.loadState('200211_12-39-09-Home1')
# run_info,dataset,evalres=utils.loadState('asghari-Home2')
#utils.saveState([run_info,dataset,{0:evalres[0]}],'asghari-Home2')
# res=an.mergeEvals(dataset,evalres,metric.MyMetric)
# res2=an.mergeEvals(dataset,evalres2,metric.MyMetric)

#vs.plotMyMetric(res,[k for k in res],dataset.activities_map)
#vs.plotMyMetric(res2,[k for k in res2],dataset.activities_map)
# vs.plotJoinMetric({'My':res2,'asghari':res},[k for k in res2],dataset.activities_map)

# %%
import unified_ar.result_analyse.SpiderChart as spiderchart
joinmetrics={'My':res2,'asghari':res}
acts=[k for k in res2]
actmap=dataset.activities_map
import matplotlib.pyplot as plt
import pandas as pd
def plotJoinMetric(joinmetrics,acts,actmap={}):
    acount=len(acts)
    col=min(4,acount)        
    row=int(np.ceil((acount)/float(col)))
    import unified_ar.result_analyse.SpiderChart
    result_analyse.SpiderChart.radar_factory(5, frame='polygon')
    m_fig,m_ax=plt.subplots(row,col,figsize=(col*3, row*3),subplot_kw=dict(projection='radar'))
    if type(m_ax)!=np.ndarray:
        m_ax=np.array([m_ax])
    m_ax=m_ax.flatten()
    
    
    for i, act in enumerate(acts):
        all=0
        name=actmap[act] if act in actmap else act
        print(name,"========")
        for item in joinmetrics:
            metrics=joinmetrics[item][act]
            if('avg' in metrics):metrics=metrics['avg']
            #plotJoinAct(dataset,real_events,pred_events,onlyAct=i)
            df=pd.DataFrame(metrics)
            print('average=',np.average(list(df.loc['f1'])))
            df=df.drop(['tp','fp','fn','recall','precision'])
            if type(all)==type(0):
                all=df.drop(['f1'])
            all.loc[item]=df.loc['f1']
        spiderchart.plot(all,[0.25,.5,.75],title=name,ax=m_ax[i])
    m_fig.tight_layout(pad=0,h_pad=-10.0, w_pad=3.0)

plotJoinMetric({'My':res2,'asghari':res},[k for k in res2],dataset.activities_map)
